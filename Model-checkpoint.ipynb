# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batchsize=8

# %%
train_datagen= ImageDataGenerator(rescale=1./255, rotation_range=0.2,shear_range=0.2,
    zoom_range=0.2,width_shift_range=0.2,
    height_shift_range=0.2, validation_split=0.2)

train_data= train_datagen.flow_from_directory(r'C:\Users\DELL\Desktop\dd\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical',subset='training' )

validation_data= train_datagen.flow_from_directory(r'C:\Users\DELL\Desktop\dd\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical', subset='validation')
# Out:
# Found 67890 images belonging to 2 classes.
# Found 16972 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_data = test_datagen.flow_from_directory(r'C:\Users\DELL\Desktop\dd\test',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical')
# Out:
# Found 4021 images belonging to 2 classes.

# %%
bmodel = InceptionV3(include_top=False, weights='imagenet', input_tensor=Input(shape=(80,80,3)))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64, activation='relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2,activation= 'softmax')(hmodel)

model = Model(inputs=bmodel.input, outputs= hmodel)
for layer in bmodel.layers:
    layer.trainable = False
# Out:
# ...
# 87924736/87910968 [==============================] - 12s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 39, 39, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 39, 39, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 39, 39, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 37, 37, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 37, 37, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 37, 37, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 37, 37, 64)   18432       ['activation_1[0][0]']
#
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping, ReduceLROnPlateau

# %%
from PIL import Image

# %%
checkpoint = ModelCheckpoint(r'C:\Users\DELL\Desktop\dd\models\model.h5',
                            monitor='val_loss',save_best_only=True,verbose=3)

earlystop = EarlyStopping(monitor = 'val_loss', patience=7, verbose= 3, restore_best_weights=True)

learning_rate = ReduceLROnPlateau(monitor= 'val_loss', patience=3, verbose= 3, )

callbacks=[checkpoint,earlystop,learning_rate]

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])

history = model.fit(train_data,steps_per_epoch=train_data.samples//batchsize,
                   validation_data=validation_data,
                   validation_steps=validation_data.samples//batchsize,
                   callbacks=callbacks,
                    epochs=10)
# Out:
# Epoch 1/10
# 8486/8486 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9328
# Epoch 1: val_loss improved from inf to 0.25367, saving model to C:\Users\DELL\Desktop\dd\models\model.h5
# 8486/8486 [==============================] - 780s 91ms/step - loss: 0.1756 - accuracy: 0.9328 - val_loss: 0.2537 - val_accuracy: 0.8929 - lr: 0.0010
# Epoch 2/10
# 8486/8486 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9359
# Epoch 2: val_loss improved from 0.25367 to 0.24665, saving model to C:\Users\DELL\Desktop\dd\models\model.h5
# 8486/8486 [==============================] - 694s 82ms/step - loss: 0.1676 - accuracy: 0.9359 - val_loss: 0.2466 - val_accuracy: 0.9117 - lr: 0.0010
# Epoch 3/10
# 8486/8486 [==============================] - ETA: 0s - loss: 0.1624 - accuracy: 0.9373
# Epoch 3: val_loss did not improve from 0.24665
# ...

# %%
acc_tr, loss_tr = model.evaluate(train_data)
print(acc_tr)
print(loss_tr)
# Out:
# 8487/8487 [==============================] - 457s 54ms/step - loss: 0.1236 - accuracy: 0.9528
# 0.12360455840826035
# 0.9528207182884216

# %%
acc_vr, loss_vr = model.evaluate(validation_data)
print(acc_vr)
print(loss_vr)
# Out:
# 2122/2122 [==============================] - 110s 52ms/step - loss: 0.2579 - accuracy: 0.9058
# 0.2578716278076172
# 0.9057859778404236

# %%
history.history
# Out:
# {'loss': [0.17563842236995697,
#   0.16755342483520508,
#   0.1623574197292328,
#   0.1618741899728775,
#   0.15744581818580627,
#   0.14430513978004456,
#   0.13807807862758636,
#   0.14172537624835968,
#   0.13837504386901855,
#   0.13706086575984955],
#  'accuracy': [0.932780385017395,
#   0.9359476566314697,
#   0.9373324513435364,
#   0.9374650120735168,
#   0.941368818283081,
#   0.9447423219680786,
#   0.9477623105049133,
#   0.9465248584747314,
#   0.9476149678230286,
#   0.9477770328521729],
#  'val_loss': [0.25366586446762085,
#   0.24664680659770966,
#   0.277197927236557,
#   0.25320956110954285,
#   0.2773130238056183,
#   0.2515622079372406,
#   0.26035216450691223,
#   0.24471822381019592,
#   0.2557240128517151,
#   0.2536517381668091],
#  'val_accuracy': [0.8929160833358765,
#   0.9116572141647339,
#   0.9005185961723328,
#   0.8976308107376099,
#   0.9009901285171509,
#   0.9057638049125671,
#   0.9045261740684509,
#   0.9072960615158081,
#   0.9059995412826538,
# ...

# %%
acc = history.history['accuracy']
loss = history.history['loss']

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(10), acc, label=' Accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy')
plt.subplot(1, 2, 2)
plt.plot(range(10), loss, label=' Loss')
plt.legend(loc='upper right')
plt.title('Loss')
plt.show()

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
plt.plot(range(10), loss_train, 'r', label='Training loss')
plt.plot(range(10), loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_train = history.history['accuracy']
acc_val = history.history['val_accuracy']
plt.plot(range(10), acc_train, 'g', label='Training accuracy')
plt.plot(range(10), acc_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
